# %%
from skimage import data
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
camera = data.camera()

# %%
plt.imshow(camera, cmap=plt.cm.gray)
plt.show()

# %%
plt.imshow(data.coffee(), cmap=plt.cm.gray)
plt.show()

# %%
data.coffee()
# Out:
# array([[[ 21,  13,   8],
#         [ 21,  13,   9],
#         [ 20,  11,   8],
#         ...,
#         [228, 182, 138],
#         [231, 185, 142],
#         [228, 184, 140]],
#
#        [[ 21,  13,   7],
#         [ 21,  13,   9],
#         [ 20,  14,   7],
#         ...,
#         [228, 182, 136],
#         [231, 185, 139],
#         [229, 183, 137]],
#
#        [[ 21,  14,   7],
#         [ 23,  13,  10],
#         [ 20,  14,   9],
#         ...,
#         [228, 182, 136],
#         [228, 184, 137],
#         [229, 185, 138]],
#
#        ...,
#        [[189, 124,  77],
#         [214, 155, 109],
#         [197, 141, 100],
#         ...,
#         [165,  86,  37],
#         [161,  82,  41],
#         [143,  67,  29]],
#
#        [[207, 148, 102],
#         [201, 142,  99],
#         [196, 140,  97],
#         ...,
#         [154,  74,  37],
#         [147,  66,  33],
#         [145,  65,  31]],
#
#        [[197, 141, 100],
#         [195, 137,  99],
#         [193, 138,  98],
#         ...,
#         [158,  73,  38],
#         [144,  64,  30],
#         [143,  60,  29]]], dtype=uint8)

# %%
data.coffee().shape
# Out:
# (400, 600, 3)

# %%
plt.imshow(data.coffee(), cmap=plt.cm.gray)

# %%
x = np.arange(0, 10, 0.1, dtype=np.float32)
y = np.sin(x)
plt.xlabel("x")
plt.ylabel("y: sin(x)")
plt.plot(x, y, label="s")
plt.legend()
plt.show()
